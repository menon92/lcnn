# %%
import os
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img_path = '../../data/york/valid/P1020171.png'
img_label = '../../data/york/valid/P1020171_label.npz'

# %%
image = cv2.imread(img_path)

# %%
plt.imshow(image)

# %%
label = np.load(img_label)

# %%
print(label)

# %%
print(dir(label))
# Out:
# ['__abstractmethods__', '__class__', '__contains__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_files', 'allow_pickle', 'close', 'f', 'fid', 'files', 'get', 'items', 'iteritems', 'iterkeys', 'keys', 'pickle_kwargs', 'values', 'zip']

# %%
print(label.files)
# Out:
# ['aspect_ratio', 'jmap', 'joff', 'lmap', 'junc', 'Lpos', 'Lneg', 'lpos', 'lneg']

# %%
for file in label.files:
    print(file, type(label[file]), label[file].shape)
# Out:
# aspect_ratio <class 'numpy.ndarray'> ()
# jmap <class 'numpy.ndarray'> (1, 128, 128)
# joff <class 'numpy.ndarray'> (1, 2, 128, 128)
# lmap <class 'numpy.ndarray'> (128, 128)
# junc <class 'numpy.ndarray'> (100, 3)
# Lpos <class 'numpy.ndarray'> (50, 2)
# Lneg <class 'numpy.ndarray'> (4000, 2)
# lpos <class 'numpy.ndarray'> (50, 2, 3)
# lneg <class 'numpy.ndarray'> (2000, 2, 3)

# %%
jmap = label['jmap'][0]
plt.imshow(jmap)

# %%
joff = label['joff'][0]
plt.imshow(joff[0])
plt.show()
plt.imshow(joff[1])
plt.show()

# %%
plt.imshow(label['lmap'])

# %%
print(label['junc'])
# Out:
# [[111.63333   99.085      0.      ]
#  [127.886665  58.295      0.      ]
#  [ 76.38      67.095      0.      ]
#  [ 70.77333   12.52       0.      ]
#  [ 46.553333  64.745      0.      ]
#  [ 27.053333  11.6        0.      ]
#  [ 51.9      103.525      0.      ]
#  [ 33.26      66.655      0.      ]
#  [ 68.96667  124.315      0.      ]
#  [ 67.57333  119.91       0.      ]
#  [ 66.793335 113.065      0.      ]
#  [ 64.7      106.145      0.      ]
#  [ 49.713333  65.845      0.      ]
#  [ 31.073334  11.245      0.      ]
#  [ 54.773335  65.1        0.      ]
#  [ 38.773335  10.92       0.      ]
#  [ 28.953333  11.135      0.      ]
#  [ 47.886665  64.715      0.      ]
#  [ 80.4       10.94       0.      ]
#  [ 83.066666  67.74       0.      ]
#  [ 99.08667   13.945      0.      ]
#  [ 96.35333   58.925      0.      ]
#  [ 69.28     111.89       0.      ]
#  [ 67.613335 105.53       0.      ]
#  [ 64.473335 104.285      0.      ]
#  [ 52.126667  67.475      0.      ]
# ...
